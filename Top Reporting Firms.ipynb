# %%
## 2021-2023
import numpy as np
import pandas as pd

# load in data
df = pd.read_csv('VAERSVAX.csv')
df.head()
# Out:
#    VAERS_ID VAX_TYPE         VAX_MANU  VAX_LOT VAX_DOSE_SERIES VAX_ROUTE  \
# 0    910642  COVID19  PFIZER\BIONTECH   EJ1685               1       NaN
# 1    916600  COVID19          MODERNA  037K20A               1        IM
# 2    916601  COVID19          MODERNA  025L20A               1        IM
# 3    916602  COVID19  PFIZER\BIONTECH   EL1284               1        IM
# 4    916603  COVID19          MODERNA  unknown             UNK       NaN
#
#   VAX_SITE                             VAX_NAME
# 0       LA  COVID19 (COVID19 (PFIZER-BIONTECH))
# 1       LA          COVID19 (COVID19 (MODERNA))
# 2       RA          COVID19 (COVID19 (MODERNA))
# 3       LA  COVID19 (COVID19 (PFIZER-BIONTECH))
# 4      NaN          COVID19 (COVID19 (MODERNA))

# %%
df.VAX_MANU.value_counts()
# Out:
# PFIZER\BIONTECH                      458789
# MODERNA                              445156
# JANSSEN                               72758
# GLAXOSMITHKLINE BIOLOGICALS           32371
# UNKNOWN MANUFACTURER                  32084
# MERCK & CO. INC.                      21012
# SANOFI PASTEUR                        15234
# SEQIRUS, INC.                          5213
# PFIZER\WYETH                           3657
# NOVARTIS VACCINES AND DIAGNOSTICS      3291
# BAVARIAN NORDIC                        1657
# PROTEIN SCIENCES CORPORATION           1148
# DYNAVAX TECHNOLOGIES CORPORATION        630
# MSP VACCINE COMPANY                     380
# NOVAVAX                                 242
# EMERGENT BIOSOLUTIONS                   209
# BERNA BIOTECH, LTD.                     163
# MEDIMMUNE VACCINES, INC.                154
# MASS. PUB HLTH BIOL LAB                  64
# TEVA PHARMACEUTICALS                     53
# INTERCELL AG                             35
# ...

# %%
PFIZERBIONTECH = df[df['VAX_MANU'] == 'PFIZER\BIONTECH'].reset_index(drop=True)
PFIZERBIONTECH.head()
# Out:
#    VAERS_ID VAX_TYPE         VAX_MANU VAX_LOT VAX_DOSE_SERIES VAX_ROUTE  \
# 0    910642  COVID19  PFIZER\BIONTECH  EJ1685               1       NaN
# 1    916602  COVID19  PFIZER\BIONTECH  EL1284               1        IM
# 2    916617  COVID19  PFIZER\BIONTECH  Eh9899               1        IM
# 3    916619  COVID19  PFIZER\BIONTECH     NaN               1        IM
# 4    916623  COVID19  PFIZER\BIONTECH     NaN               1        IM
#
#   VAX_SITE                             VAX_NAME
# 0       LA  COVID19 (COVID19 (PFIZER-BIONTECH))
# 1       LA  COVID19 (COVID19 (PFIZER-BIONTECH))
# 2       LA  COVID19 (COVID19 (PFIZER-BIONTECH))
# 3       LA  COVID19 (COVID19 (PFIZER-BIONTECH))
# 4       LA  COVID19 (COVID19 (PFIZER-BIONTECH))

# %%
MODERNA = df[df['VAX_MANU'] == 'MODERNA'].reset_index(drop=True)
MODERNA.head()
# Out:
#    VAERS_ID VAX_TYPE VAX_MANU  VAX_LOT VAX_DOSE_SERIES VAX_ROUTE VAX_SITE  \
# 0    916600  COVID19  MODERNA  037K20A               1        IM       LA
# 1    916601  COVID19  MODERNA  025L20A               1        IM       RA
# 2    916603  COVID19  MODERNA  unknown             UNK       NaN      NaN
# 3    916604  COVID19  MODERNA      NaN               1        IM       LA
# 4    916606  COVID19  MODERNA  011J20A               1        IM       LA
#
#                       VAX_NAME
# 0  COVID19 (COVID19 (MODERNA))
# 1  COVID19 (COVID19 (MODERNA))
# 2  COVID19 (COVID19 (MODERNA))
# 3  COVID19 (COVID19 (MODERNA))
# 4  COVID19 (COVID19 (MODERNA))

# %%
JANSSEN = df[df['VAX_MANU'] == 'JANSSEN'].reset_index(drop=True)
JANSSEN.head()
# Out:
#    VAERS_ID VAX_TYPE VAX_MANU   VAX_LOT VAX_DOSE_SERIES VAX_ROUTE VAX_SITE  \
# 0   1067448  COVID19  JANSSEN       NaN             UNK       NaN      NaN
# 1   1070055  COVID19  JANSSEN   1802068               1        IM       RA
# 2   1070546  COVID19  JANSSEN       NaN               1        IM       LA
# 3   1070883  COVID19  JANSSEN   1805018               1        IM       RA
# 4   1070975  COVID19  JANSSEN  10805018               1        IM       LA
#
#                       VAX_NAME
# 0  COVID19 (COVID19 (JANSSEN))
# 1  COVID19 (COVID19 (JANSSEN))
# 2  COVID19 (COVID19 (JANSSEN))
# 3  COVID19 (COVID19 (JANSSEN))
# 4  COVID19 (COVID19 (JANSSEN))

# %%
GLAXOSMITHKLINE = df[df['VAX_MANU'] == 'GLAXOSMITHKLINE BIOLOGICALS'].reset_index(drop=True)
GLAXOSMITHKLINE.head()
# Out:
#    VAERS_ID    VAX_TYPE                     VAX_MANU VAX_LOT VAX_DOSE_SERIES  \
# 0    916616  DTAPHEPBIP  GLAXOSMITHKLINE BIOLOGICALS     NaN             UNK
# 1    916616         RV1  GLAXOSMITHKLINE BIOLOGICALS     NaN               1
# 2    916715      VARZOS  GLAXOSMITHKLINE BIOLOGICALS   2S9CL               2
# 3    916718      VARZOS  GLAXOSMITHKLINE BIOLOGICALS     NaN               2
# 4    916806      VARZOS  GLAXOSMITHKLINE BIOLOGICALS   9K4T4               2
#
#   VAX_ROUTE VAX_SITE                      VAX_NAME
# 0       NaN       LG  DTAP + HEPB + IPV (PEDIARIX)
# 1        PO       MO           ROTAVIRUS (ROTARIX)
# 2        IM       RA             ZOSTER (SHINGRIX)
# 3       SYR       LA             ZOSTER (SHINGRIX)
# 4        IM       LA             ZOSTER (SHINGRIX)

# %%
MERCK = df[df['VAX_MANU'] == 'MERCK & CO. INC.'].reset_index(drop=True)
MERCK.head()
# Out:
#    VAERS_ID VAX_TYPE          VAX_MANU  VAX_LOT VAX_DOSE_SERIES VAX_ROUTE  \
# 0    916616     HIBV  MERCK & CO. INC.      NaN             UNK       NaN
# 1    916684      PPV  MERCK & CO. INC.      NaN               1        IM
# 2    916737      MMR  MERCK & CO. INC.  s029456               1        SC
# 3    917126     HPV9  MERCK & CO. INC.      NaN               2        IM
# 4    917129      MMR  MERCK & CO. INC.      NaN             UNK       NaN
#
#   VAX_SITE                            VAX_NAME
# 0       LG                     HIB (PEDVAXHIB)
# 1       RA                  PNEUMO (PNEUMOVAX)
# 2       RL  MEASLES + MUMPS + RUBELLA (MMR II)
# 3       LA                    HPV (GARDASIL 9)
# 4      NaN  MEASLES + MUMPS + RUBELLA (MMR II)
