# %%
import pandas as pd
import glob
from functools import reduce
    
def merge_csv_files(input_files, output_file_name):

    # Merge multiple CSV files in a folder into a single CSV file

    df_list = []

    for filename in input_files:
        df = pd.read_csv(filename, index_col=None, header=0, dtype = 'object', encoding= 'latin1')
        df_list.append(df)

    df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['VAERS_ID'],
                                            how='outer'), df_list.fillna('void')
    
    #combined_df.to_csv(output_file_name, index=False)
    #print(df_list)
    
    pd.DataFrame.to_csv(df_merged, output_file_name, sep=',', index=False)
   
merge_csv_files(["2021VAERSVAX.csv","2021VAERSDATA.csv","2021VAERSSYMPTOMS.csv"], "2021VAERS_Merged.csv")

# %%
df = pd.read_csv("2021VAERS_Merged.csv", index_col=None, header=0, dtype = 'object', encoding= 'latin1')
print(df.head())
# Out:
#   VAERS_ID VAX_TYPE         VAX_MANU  VAX_LOT VAX_DOSE_SERIES VAX_ROUTE  \
# 0  0910642  COVID19  PFIZER\BIONTECH   EJ1685               1      void
# 1  0916600  COVID19          MODERNA  037K20A               1        IM
# 2  0916601  COVID19          MODERNA  025L20A               1        IM
# 3  0916602  COVID19  PFIZER\BIONTECH   EL1284               1        IM
# 4  0916603  COVID19          MODERNA  unknown             UNK      void
#
#   VAX_SITE                             VAX_NAME    RECVDATE STATE  ...  \
# 0       LA  COVID19 (COVID19 (PFIZER-BIONTECH))  01/04/2021    CO  ...
# 1       LA          COVID19 (COVID19 (MODERNA))  01/01/2021    TX  ...
# 2       RA          COVID19 (COVID19 (MODERNA))  01/01/2021    CA  ...
# 3       LA  COVID19 (COVID19 (PFIZER-BIONTECH))  01/01/2021    WA  ...
# 4     void          COVID19 (COVID19 (MODERNA))  01/01/2021    WA  ...
#
#            SYMPTOM1 SYMPTOMVERSION1              SYMPTOM2 SYMPTOMVERSION2  \
# 0          Dyspnoea           25.00  Heart rate increased           25.00
# 1         Dysphagia           23.10          Epiglottitis           23.10
# 2           Anxiety           23.10              Dyspnoea           23.10
# 3  Chest discomfort           23.10             Dysphagia           23.10
# 4         Dizziness           23.10               Fatigue           23.10
#
#                    SYMPTOM3 SYMPTOMVERSION3           SYMPTOM4  \
# 0  SARS-CoV-2 test negative           25.00               void
# 1                      void            void               void
# 2                      void            void               void
# 3         Pain in extremity           23.10  Visual impairment
# 4        Mobility decreased           23.10               void
#
#   SYMPTOMVERSION4 SYMPTOM5 SYMPTOMVERSION5
# 0            void     void            void
# 1            void     void            void
# 2            void     void            void
# 3           23.10     void            void
# 4            void     void            void
#
# [5 rows x 52 columns]

# %%
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from gensim import corpora, models
import gensim

df = pd.read_csv("vaers/2023VAERSSYMPTOMS.csv")

tokenizer = RegexpTokenizer(r'\w+')

# create English stop words list
en_stop = nltk.corpus.stopwords.words('english')

# Create p_stemmer of class PorterStemmer
p_stemmer = nltk.stem.snowball.PorterStemmer(ignore_stopwords=False).stem

# list for tokenized documents in loop
texts = []

# loop through document list
for i in df.SYMPTOM1:
    
    # clean and tokenize document string
    raw = i.lower()
    tokens = tokenizer.tokenize(raw)

    # remove stop words from tokens
    stopped_tokens = [i for i in tokens if not i in en_stop]
    
    # stem tokens
    stemmed_tokens = [word_rooter(i) for i in stopped_tokens]
    
    # add tokens to list
    texts.append(stemmed_tokens)
    
# turn our tokenized documents into a id <-> term dictionary
dictionary = corpora.Dictionary(texts)
    
# convert tokenized documents into a document-term matrix
corpus = [dictionary.doc2bow(text) for text in texts]

# generate LDA model
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=3, id2word = dictionary, passes=20)
print(ldamodel.print_topics(num_topics=3, num_words=3))
# Out:
# [(0, '0.177*"administ" + 0.149*"product" + 0.093*"expir"'), (1, '0.136*"product" + 0.135*"19" + 0.135*"covid"'), (2, '0.060*"event" + 0.051*"advers" + 0.049*"test"')]

# %%
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from gensim import corpora, models
import gensim

df = pd.read_csv("vaers/2023VAERSSYMPTOMS.csv")

tokenizer = RegexpTokenizer(r'\w+')

# create English stop words list
en_stop = nltk.corpus.stopwords.words('english')

# Create p_stemmer of class PorterStemmer
p_stemmer = nltk.stem.snowball.PorterStemmer(ignore_stopwords=False).stem

# list for tokenized documents in loop
texts = []

# loop through document list
for i in df.SYMPTOM1:
    
    # clean and tokenize document string
    raw = i.lower()
    tokens = tokenizer.tokenize(raw)

    # remove stop words from tokens
    stopped_tokens = [i for i in tokens if not i in en_stop]
    
    # stem tokens
    stemmed_tokens = [word_rooter(i) for i in stopped_tokens]
    
    # add tokens to list
    texts.append(stemmed_tokens)
    
# Import the wordcloud library
from wordcloud import WordCloud
import os
from os import path

# Converts arrray to txt file
with open("wordcloud.txt", "w") as txt_file:
    for line in texts:
        txt_file.write(" ".join(line) + "\n") # works with any number of elements in a line

#open text file in read mode
text_file = open("vaers/wordcloud.txt", "r")

#read whole file to a string
data = text_file.read()

#close file
text_file.close()        
        
# Create a WordCloud object
wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=3, contour_color='steelblue')
# Generate a word cloud
wordcloud.generate(data)
# Visualize the word cloud
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
pip install nltk
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from gensim import corpora, models
import gensim

df = pd.read_csv("2022VAERSSYMPTOMS.csv")
df = df.astype(str)

tokenizer = RegexpTokenizer(r'\w+')

# create English stop words list
en_stop = nltk.corpus.stopwords.words('english')

# Create p_stemmer of class PorterStemmer
p_stemmer = nltk.stem.snowball.PorterStemmer(ignore_stopwords=False).stem

# list for tokenized documents in loop
texts = []

# loop through document list
for i in df.SYMPTOM1:
    
    # clean and tokenize document string
    raw = i.lower()
    tokens = tokenizer.tokenize(raw)

    # remove stop words from tokens
    stopped_tokens = [i for i in tokens if not i in en_stop]
    
    letter_tokens = [re.sub('([0-9]+)', '', i) for i in stopped_tokens]
    
    # stem tokens
    stemmed_tokens = [word_rooter(i) for i in letter_tokens]
    
    # add tokens to list
    texts.append(stemmed_tokens)

for i in df.SYMPTOM2:
    
    # clean and tokenize document string
    raw = i.lower()
    tokens = tokenizer.tokenize(raw)

    # remove stop words from tokens
    stopped_tokens = [i for i in tokens if not i in en_stop]
    
    letter_tokens = [re.sub('([0-9]+)', '', i) for i in stopped_tokens]
    
    # stem tokens
    stemmed_tokens = [word_rooter(i) for i in letter_tokens]
    
    # add tokens to list
    texts.append(stemmed_tokens)
    
for i in df.SYMPTOM3:
    
    # clean and tokenize document string
    raw = i.lower()
    tokens = tokenizer.tokenize(raw)

    # remove stop words from tokens
    stopped_tokens = [i for i in tokens if not i in en_stop]
    
    letter_tokens = [re.sub('([0-9]+)', '', i) for i in stopped_tokens]
    
    # stem tokens
    stemmed_tokens = [word_rooter(i) for i in letter_tokens]
    
    # add tokens to list
    texts.append(stemmed_tokens)
    
for i in df.SYMPTOM4:
    
    # clean and tokenize document string
    raw = i.lower()
    tokens = tokenizer.tokenize(raw)

    # remove stop words from tokens
    stopped_tokens = [i for i in tokens if not i in en_stop]
    
    letter_tokens = [re.sub('([0-9]+)', '', i) for i in stopped_tokens]
    
    # stem tokens
    stemmed_tokens = [word_rooter(i) for i in letter_tokens]
    
    # add tokens to list
    texts.append(stemmed_tokens)
    
for i in df.SYMPTOM5:
    
    # clean and tokenize document string
    raw = i.lower()
    tokens = tokenizer.tokenize(raw)

    # remove stop words from tokens
    stopped_tokens = [i for i in tokens if not i in en_stop]
    
    letter_tokens = [re.sub('([0-9]+)', '', i) for i in stopped_tokens]
    
    # stem tokens
    stemmed_tokens = [word_rooter(i) for i in letter_tokens]
    
    # add tokens to list
    texts.append(stemmed_tokens)

# turn our tokenized documents into a id <-> term dictionary
dictionary = corpora.Dictionary(texts)
    
# convert tokenized documents into a document-term matrix
corpus = [dictionary.doc2bow(text) for text in texts]

# generate LDA model
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=3, id2word = dictionary, passes=10)
print(ldamodel.print_topics(num_topics=3, num_words=3))
# Out:
#   File "/var/folders/pv/fg7xy3q55sg_wql_kq5dp60h0000gn/T/ipykernel_52721/3443165871.py", line 1
#     pip install nltk
#         ^
# SyntaxError: invalid syntax

# %%
# Finding Age Distributions
import pandas as pd
import numpy as np

# load in data
age=[]
df = pd.read_csv("2021VAERS_Merged.csv", index_col=None, header=0, dtype = 'object', encoding= 'latin1')

# replace empty cells with -1 (-1 represents void cells)
df['AGE_YRS'].replace('void', -1, inplace=True)

# change dtype of list
df['AGE_YRS'] = df['AGE_YRS'].astype(float)
df['AGE_YRS'] = df['AGE_YRS'].astype(int)

# count and group age data
age = pd.cut(df['AGE_YRS'], [-10,0,12,18,30,50,70,120], include_lowest=True)
age_count = age.value_counts()

# %%
from matplotlib import pyplot as plt

# %%
print(age_count)
print(type(age_count))
print(age_count.argsort(0))
# Out:
# (50.0, 70.0]      327358
# (30.0, 50.0]      310392
# (70.0, 120.0]     147198
# (18.0, 30.0]      115029
# (-10.001, 0.0]     99095
# (12.0, 18.0]       37259
# (0.0, 12.0]        19635
# Name: AGE_YRS, dtype: int64
# <class 'pandas.core.series.Series'>
# (50.0, 70.0]      6
# (30.0, 50.0]      5
# (70.0, 120.0]     4
# (18.0, 30.0]      3
# (-10.001, 0.0]    2
# (12.0, 18.0]      1
# (0.0, 12.0]       0
# Name: AGE_YRS, dtype: int64

# %%
# Creating histogram
fig, ax = plt.subplots(figsize =(10, 7))

x = ['Empty','0-12','12-18','18-30','30-50','50-70','70-120'] 
y = [age_count[0], age_count[12], age_count[18], age_count[30], age_count[50], age_count[70], age_count[120]]

ax.bar(x, y, color = '#40826D', edgecolor='#40826D', linewidth=2)
ax.set_xlabel('Age Range (Years)')
ax.set_ylabel('Density')

# Show plot
plt.show()
